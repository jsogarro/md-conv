# %% [markdown]
# # Documentation Notebook
#
# This notebook contains only markdown cells.

# %% [markdown]
# ## Features
#
# - **Bold text**
# - *Italic text*
# - `Inline code`

# %% [markdown]
# ## Table Example
#
# | Column A | Column B |
# |----------|----------|
# | Value 1  | Value 2  |
